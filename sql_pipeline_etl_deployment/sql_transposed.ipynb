# %%
import os
import pandas as pd

# Define the folder containing the files
folder_path = "Financial_Statements_16_Companies"

# Get all Excel files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.endswith(".xlsx")]

# Function to clean the "Fiscal Quarter" column
def clean_fiscal_quarter(value):
    value = str(value)
    if "Current" in value:
        return " ".join(value.split()[-2:])  # Keep "Current YYYY"
    elif "Q" in value:
        parts = value.split()
        return f"{parts[-2]} {parts[-1]}"  # Keep "QX YYYY"
    return value

# Loop through each file
for file in excel_files:
    file_path = os.path.join(folder_path, file)
    
    # Explicitly specify 'openpyxl' for .xlsx files
    try:
        with pd.ExcelFile(file_path, engine="openpyxl") as xls:
            sheet_names = xls.sheet_names
            processed_sheets = {}

            for sheet in sheet_names:
                df = pd.read_excel(xls, sheet_name=sheet, engine="openpyxl")
                
                if "Fiscal Quarter" in df.columns:
                    df["Fiscal Quarter"] = df["Fiscal Quarter"].apply(clean_fiscal_quarter)

                # Store the cleaned DataFrame
                processed_sheets[sheet] = df

        # Save the cleaned data to a new file
        output_path = os.path.join(folder_path, f"cleaned_{file}")
        with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
            for sheet, df in processed_sheets.items():
                df.to_excel(writer, sheet_name=sheet, index=False)

        print(f"Processed and saved: {file}")

    except Exception as e:
        print(f"Error processing {file}: {e}")

print("Processing complete.")
# Out:
# Processed and saved: financial_statements_goog.xlsx
# Processed and saved: financial_statements_vz.xlsx
# Processed and saved: financial_statements_ko.xlsx
# Processed and saved: financial_statements_mcd.xlsx
# Processed and saved: cleaned_financial_statements_amd.xlsx
# Processed and saved: financial_statements_meta.xlsx
# Processed and saved: financial_statements_shel.xlsx
# Processed and saved: financial_statements_t.xlsx
# Processed and saved: financial_statements_jpm.xlsx
# Processed and saved: financial_statements_pep.xlsx
# Processed and saved: financial_statements_amd.xlsx
# Processed and saved: financial_statements_amzn.xlsx
# Processed and saved: financial_statements_ma.xlsx
# Processed and saved: financial_statements_tsla.xlsx
# Processed and saved: financial_statements_spgi.xlsx
# Processed and saved: financial_statements_nflx.xlsx
# Processed and saved: financial_statements_hsbc.xlsx
# Processing complete.

# %%
import re

# Define the folder containing cleaned files
folder_path = "Financial_Statements_16_Companies/cleaned_data/clean_names/"

# Get all cleaned Excel files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.startswith("cleaned_financial_statements_") and f.endswith(".xlsx")]

# Rename files
for file in excel_files:
    # Extract company name using regex
    match = re.search(r"cleaned_financial_statements_(.+)\.xlsx", file)
    if match:
        company_name = match.group(1)  # Extract company name
        new_file_name = f"{company_name}.xlsx"  # New filename
        
        # Define old and new file paths
        old_path = os.path.join(folder_path, file)
        new_path = os.path.join(folder_path, new_file_name)

        # Rename the file
        os.rename(old_path, new_path)
        print(f"Renamed: {file} -> {new_file_name}")

print("Renaming complete.")
# Out:
# Renamed: cleaned_financial_statements_jpm.xlsx -> jpm.xlsx
# Renamed: cleaned_financial_statements_meta.xlsx -> meta.xlsx
# Renamed: cleaned_financial_statements_t.xlsx -> t.xlsx
# Renamed: cleaned_financial_statements_shel.xlsx -> shel.xlsx
# Renamed: cleaned_financial_statements_amd.xlsx -> amd.xlsx
# Renamed: cleaned_financial_statements_pep.xlsx -> pep.xlsx
# Renamed: cleaned_financial_statements_goog.xlsx -> goog.xlsx
# Renamed: cleaned_financial_statements_ma.xlsx -> ma.xlsx
# Renamed: cleaned_financial_statements_ko.xlsx -> ko.xlsx
# Renamed: cleaned_financial_statements_hsbc.xlsx -> hsbc.xlsx
# Renamed: cleaned_financial_statements_nflx.xlsx -> nflx.xlsx
# Renamed: cleaned_financial_statements_spgi.xlsx -> spgi.xlsx
# Renamed: cleaned_financial_statements_amzn.xlsx -> amzn.xlsx
# Renamed: cleaned_financial_statements_mcd.xlsx -> mcd.xlsx
# Renamed: cleaned_financial_statements_vz.xlsx -> vz.xlsx
# Renamed: cleaned_financial_statements_tsla.xlsx -> tsla.xlsx
# Renaming complete.

# %%
import os
import pandas as pd

# Define the folder containing the cleaned Excel files
folder_path = "Financial_Statements_16_companies/cleaned_data/clean_names/"

# Get all Excel files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.endswith(".xlsx")]

# Process each file
for file in excel_files:
    file_path = os.path.join(folder_path, file)
    
    try:
        # Load the Excel file
        with pd.ExcelFile(file_path, engine="openpyxl") as xls:
            sheet_names = xls.sheet_names  # Get all sheet names
            processed_sheets = {}

            for i, sheet in enumerate(sheet_names):
                df = pd.read_excel(xls, sheet_name=sheet, engine="openpyxl")

                # Keep only first 8 rows except for the last sheet, which gets 9 rows
                if i == len(sheet_names) - 1:
                    df = df.iloc[:10]  # Last sheet -> 9 rows
                else:
                    df = df.iloc[:9]  # Other sheets -> 8 rows

                processed_sheets[sheet] = df  # Store the processed DataFrame

        # Save the modified data back to the same file
        with pd.ExcelWriter(file_path, engine="openpyxl") as writer:
            for sheet, df in processed_sheets.items():
                df.to_excel(writer, sheet_name=sheet, index=False)

        print(f"Processed and saved: {file}")

    except Exception as e:
        print(f"Error processing {file}: {e}")

print("Processing complete.")
# Out:
# Processed and saved: meta.xlsx
# Processed and saved: shel.xlsx
# Processed and saved: mcd.xlsx
# Processed and saved: ko.xlsx
# Processed and saved: goog.xlsx
# Processed and saved: vz.xlsx
# Processed and saved: jpm.xlsx
# Processed and saved: amzn.xlsx
# Processed and saved: tsla.xlsx
# Processed and saved: nflx.xlsx
# Processed and saved: spgi.xlsx
# Processed and saved: hsbc.xlsx
# Processed and saved: ma.xlsx
# Processed and saved: amd.xlsx
# Processed and saved: pep.xlsx
# Processed and saved: t.xlsx
# Processing complete.

# %%
import os
import pandas as pd

# Define the folder containing the Excel files
folder_path = "Financial_Statements_16_companies/cleaned_data/clean_names/transposed/"

# Get all Excel files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.endswith(".xlsx")]

# Process each file
for file in excel_files:
    file_path = os.path.join(folder_path, file)
    
    try:
        # Load the Excel file
        with pd.ExcelFile(file_path, engine="openpyxl") as xls:
            sheet_names = xls.sheet_names  # Get all sheet names
            transposed_sheets = {}

            for sheet in sheet_names:
                df = pd.read_excel(xls, sheet_name=sheet, engine="openpyxl")

                # Transpose the DataFrame but keep original column names in the first column
                df_transposed = df.set_index(df.columns[0]).T.reset_index()

                # Rename the first column to "Metrics"
                df_transposed.rename(columns={df_transposed.columns[0]: "Metrics"}, inplace=True)

                transposed_sheets[sheet] = df_transposed  # Store the transposed DataFrame

        # Overwrite the original file with transposed data
        with pd.ExcelWriter(file_path, engine="openpyxl") as writer:
            for sheet, df in transposed_sheets.items():
                df.to_excel(writer, sheet_name=sheet, index=False)

        print(f"Transposed and overwritten: {file}")

    except Exception as e:
        print(f"Error processing {file}: {e}")

print("Transposing complete.")
# Out:
# Transposed and overwritten: meta.xlsx
# Transposed and overwritten: shel.xlsx
# Transposed and overwritten: mcd.xlsx
# Transposed and overwritten: ko.xlsx
# Transposed and overwritten: goog.xlsx
# Transposed and overwritten: vz.xlsx
# Transposed and overwritten: jpm.xlsx
# Transposed and overwritten: amzn.xlsx
# Transposed and overwritten: tsla.xlsx
# Transposed and overwritten: nflx.xlsx
# Transposed and overwritten: spgi.xlsx
# Transposed and overwritten: hsbc.xlsx
# Transposed and overwritten: ma.xlsx
# Transposed and overwritten: amd.xlsx
# Transposed and overwritten: pep.xlsx
# Transposed and overwritten: t.xlsx
# Transposing complete.

# %%
import os
import pandas as pd
import re

# Define input and output folders
input_folder = "Financial_Statements_16_Companies/cleaned_data/clean_names/transposed/"
output_folder = "/Users/vexy/Documents/aip/code/scripts/data/cleaned_scraped_data/"
# Ensure output directory exists
os.makedirs(output_folder, exist_ok=True)

# Get all Excel files in the folder
excel_files = [f for f in os.listdir(input_folder) if f.endswith(".xlsx")]

# Function to clean column names
def clean_column_name(col_name):
    col_name = re.sub(r"[()]", "_", col_name)  # Replace brackets with underscores
    col_name = col_name.replace("&", " and ")  # Replace '&' with ' and ' (extra space before and after)
    col_name = re.sub(r"\s+", "_", col_name)  # Replace spaces with underscores
    return col_name

# Function to clean numerical values
def clean_numeric_value(value):
    if pd.isna(value) or value == "-":  # Replace missing values and "-"
        return "N/A"
    value = str(value).strip()
    if value.endswith("%"):  # Convert percentages to decimals
        try:
            return float(value.replace("%", "")) / 100
        except ValueError:
            return "N/A"
    try:
        return float(value)  # Convert normal numbers to float
    except ValueError:
        return "N/A"

# Function to clean the first column (textual data)
def clean_first_column(value):
    if pd.isna(value):
        return "N/A"
    value = str(value)
    value = re.sub(r"[()]", "", value)  # Remove parentheses without adding space
    value = value.replace("&", " and ")  # Replace '&' with ' and ' (extra space before and after)
    value = value.replace("'", "")  # Remove apostrophes
    value = re.sub(r"-", " ", value)  # Replace '-' with a space
    value = value.replace(",", "")  # Remove commas
    value = re.sub(r"/", " with ", value)  # Replace '/' with ' with ' (extra spaces added)
    value = re.sub(r"\s+", " ", value).strip()  # Remove extra spaces
    return value

# Process each file
for file in excel_files:
    file_path = os.path.join(input_folder, file)
    output_path = os.path.join(output_folder, file)  # Save in the output folder
    
    try:
        # Load the Excel file
        with pd.ExcelFile(file_path, engine="openpyxl") as xls:
            sheet_names = xls.sheet_names  # Get all sheet names
            cleaned_sheets = {}

            for sheet in sheet_names:
                df = pd.read_excel(xls, sheet_name=sheet, engine="openpyxl")

                # Clean column names
                df.columns = [clean_column_name(col) for col in df.columns]

                # Clean the first column
                df[df.columns[0]] = df[df.columns[0]].apply(clean_first_column)

                # Clean numerical values (except first column)
                for col in df.columns[1:]:  # Skip first column
                    df[col] = df[col].apply(clean_numeric_value)

                cleaned_sheets[sheet] = df  # Store the cleaned DataFrame

        # Save cleaned data
        with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
            for sheet, df in cleaned_sheets.items():
                df.to_excel(writer, sheet_name=sheet, index=False)

        print(f"Cleaned and saved: {file}")

    except Exception as e:
        print(f"Error processing {file}: {e}")

print("Cleaning complete. Files saved to:", output_folder)
# Out:
# Cleaned and saved: meta.xlsx
# Cleaned and saved: shel.xlsx
# Cleaned and saved: mcd.xlsx
# Cleaned and saved: ko.xlsx
# Cleaned and saved: goog.xlsx
# Cleaned and saved: vz.xlsx
# Cleaned and saved: jpm.xlsx
# Cleaned and saved: amzn.xlsx
# Cleaned and saved: tsla.xlsx
# Cleaned and saved: nflx.xlsx
# Cleaned and saved: spgi.xlsx
# Cleaned and saved: hsbc.xlsx
# Cleaned and saved: ma.xlsx
# Cleaned and saved: amd.xlsx
# Cleaned and saved: pep.xlsx
# Cleaned and saved: t.xlsx
# Cleaning complete. Files saved to: /Users/vexy/Documents/aip/code/scripts/data/cleaned_scraped_data/

# %%
import os
import pandas as pd
import oracledb
import numpy as np

# Oracle DB connection details
user = "ADMIN"
password = "Passwordtestdb@1"
dsn = "testdb_medium"
wallet_location = r"/Users/vexy/Documents/Wallet_testdb/"

# Connect to Oracle DB
conn = oracledb.connect(
    user=user,
    password=password,
    dsn=dsn,
    config_dir=wallet_location,
    wallet_location=wallet_location,
    wallet_password=password
)
cursor = conn.cursor()

# Ensure the session is using the ADMIN schema
cursor.execute("ALTER SESSION SET CURRENT_SCHEMA = ADMIN")

# Define the folder containing the Excel files
folder_path = "cleaned_scraped_data"

# Get all Excel files in the folder
excel_files = [f for f in os.listdir(folder_path) if f.endswith(".xlsx")]

# Function to clean and ensure unique column names
def clean_column_names(columns):
    seen = set()
    new_columns = []
    for i, col in enumerate(columns):
        col = col.strip().lower().replace(" ", "_").replace("&", "and").replace("(", "_").replace(")", "_")
        if col == "":
            col = f"col_{i}"  # Ensure no empty column names
        original_col = col
        count = 1
        while col in seen:  # Ensure uniqueness
            col = f"{original_col}_{count}"
            count += 1
        seen.add(col)
        new_columns.append(col)
    return new_columns

# Function to format table name
def format_table_name(company, sheet_name):
    sheet_name = sheet_name.lower().replace(" ", "_")
    return f"{company}_{sheet_name}".upper()  # Convert to uppercase for Oracle

import time
import oracledb

import time
import oracledb

def drop_table_forcefully(cursor, conn, table_name, max_retries=5, wait_time=2):
    """Forcefully drops a table, retrying if it's locked."""
    for attempt in range(max_retries):
        try:
            print(f"Attempting to drop table {table_name} (Attempt {attempt + 1}/{max_retries})")
            
            # Set DDL lock timeout to wait before erroring out
            cursor.execute("ALTER SESSION SET DDL_LOCK_TIMEOUT = 10")  
            
            # Try dropping the table
            cursor.execute(f'DROP TABLE "{table_name}" CASCADE CONSTRAINTS PURGE')
            conn.commit()
            
            print(f"✅ Successfully dropped table {table_name}")
            return
        except oracledb.DatabaseError as e:
            error_code = e.args[0].code
            
            if error_code == 54:  # ORA-00054: resource busy
                print(f"⚠️ Table {table_name} is locked. Checking for active locks...")
                
                # Get session holding the lock
                cursor.execute(f"""
                    SELECT SID, SERIAL# FROM V$LOCK 
                    WHERE TYPE = 'TM' AND ID1 IN (
                        SELECT OBJECT_ID FROM DBA_OBJECTS WHERE OBJECT_NAME = '{table_name}'
                    )
                """)
                
                lock_info = cursor.fetchone()
                
                if lock_info:
                    sid, serial = lock_info
                    print(f"🔴 Lock detected on {table_name}: SID={sid}, SERIAL#={serial}")
                    
                    try:
                        cursor.execute(f"ALTER SYSTEM KILL SESSION '{sid},{serial}' IMMEDIATE")
                        conn.commit()
                        print(f"✅ Killed session {sid},{serial} to release lock.")
                    except oracledb.DatabaseError as kill_error:
                        print(f"⚠️ Could not kill session: {kill_error}")

                print(f"Retrying in {wait_time} seconds...")
                time.sleep(wait_time)
            else:
                raise  # Raise other errors if they're not lock-related

    print(f"❌ Failed to drop table {table_name} after {max_retries} attempts.")

def table_exists(cursor, table_name):
    """Checks if a table exists in the current schema."""
    cursor.execute(f"SELECT COUNT(*) FROM ALL_TABLES WHERE TABLE_NAME = '{table_name}'")
    return cursor.fetchone()[0] > 0

def create_table(cursor, conn, table_name, df):
    """Creates a table, dropping it first if it already exists."""
    df.columns = clean_column_names(df.columns)
    table_name = table_name.upper()

    print(f"Checking if table {table_name} exists...")

    # Drop table if it already exists
    if table_exists(cursor, table_name):
        drop_table_forcefully(cursor, conn, table_name)

    print(f"Creating table {table_name} with columns: {df.columns}")

    # Define columns
    columns = ['"METRICS" VARCHAR2(255)']
    for col in df.columns[1:]:
        if df[col].dropna().apply(lambda x: isinstance(x, (int, float))).all():
            columns.append(f'"{col.upper()}" FLOAT')
        else:
            columns.append(f'"{col.upper()}" VARCHAR2(255)')

    create_sql = f'CREATE TABLE "{table_name}" ({", ".join(columns)})'


    # Create new table
    cursor.execute(create_sql)
    conn.commit()  # Ensure table creation is saved
    print(f"Created table: {table_name}")



def insert_data(cursor, conn, table_name, df):
    """Inserts cleaned data into the table, ensuring NaN is properly converted to NULL."""
    
    table_name = table_name.upper()  # Ensure table name matches Oracle’s case

    # Fetch column names from Oracle
    cursor.execute(f"SELECT COLUMN_NAME FROM ALL_TAB_COLUMNS WHERE TABLE_NAME = '{table_name}' ORDER BY COLUMN_ID")
    db_columns = [row[0] for row in cursor.fetchall()]

    if not db_columns:
        print(f"Skipping {table_name} - Table does not exist.")
        return

    # Ensure column names match Oracle's uppercase format
    df = df.rename(columns=lambda x: x.upper())

    # Convert 'N/A' and empty strings to NaN (which will become NULL in Oracle)
    df.replace(["N/A", ""], np.nan, inplace=True)

    # Convert numeric columns to FLOAT (force invalid strings to NaN)
    for col in df.columns:
        if col in db_columns and col != "METRICS":  # Exclude the 'METRICS' column
            df[col] = pd.to_numeric(df[col], errors="coerce")  # Convert invalid strings to NaN

    # 🔹 Ensure all NaN values are explicitly converted to None (for Oracle NULL)
    df = df.astype(object).where(pd.notna(df), None)

    print(f"Inserting into {table_name} with columns: {db_columns}")  # Debugging

    # Prepare SQL statement
    cols = '", "'.join(db_columns)
    placeholders = ", ".join([f":{i+1}" for i in range(len(db_columns))])
    insert_sql = f'INSERT INTO "{table_name}" ("{cols}") VALUES ({placeholders})'

    for _, row in df.iterrows():
        values = []
        for val in row:
            if isinstance(val, (int, float)):  # If it's numeric, ensure it's float
                values.append(float(val))
            elif val is None:  # Ensure None is correctly inserted as NULL
                values.append(None)
            else:
                values.append(str(val))  # Ensure text columns remain strings

        # Ensure number of values matches columns
        if len(values) == len(db_columns):
            try:
                cursor.execute(insert_sql, values)
            except oracledb.DatabaseError as e:
                print(f"❌ Error inserting row: {values}")
                print(f"Oracle Error: {e}")
                continue  # Instead of skipping, continue inserting valid rows

    conn.commit()
    print(f"✅ Inserted data into: {table_name}")


# Process each file
for file in excel_files:
    file_path = os.path.join(folder_path, file)
    company_name = file.replace(".xlsx", "").lower()

    with pd.ExcelFile(file_path, engine="openpyxl") as xls:
        sheet_names = xls.sheet_names

        for sheet in sheet_names:
            df = pd.read_excel(xls, sheet_name=sheet, engine="openpyxl")

            table_name = format_table_name(company_name, sheet)

            df.rename(columns={df.columns[0]: "Metrics"}, inplace=True)

            create_table(cursor, conn, table_name, df)

            insert_data(cursor, conn, table_name, df)

# Close the connection
cursor.close()
conn.close()

print("All files and sheets uploaded successfully.")
# Out:
# Checking if table META_INCOME_QUARTERLY exists...
# Attempting to drop table META_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table META_INCOME_QUARTERLY
# Creating table META_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: META_INCOME_QUARTERLY
# Inserting into META_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: META_INCOME_QUARTERLY
# Checking if table META_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table META_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table META_BALANCE_SHEET_QUARTERLY
# Creating table META_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: META_BALANCE_SHEET_QUARTERLY
# Inserting into META_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: META_BALANCE_SHEET_QUARTERLY
# Checking if table META_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table META_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table META_CASH_FLOW_QUARTERLY
# Creating table META_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: META_CASH_FLOW_QUARTERLY
# Inserting into META_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: META_CASH_FLOW_QUARTERLY
# Checking if table META_RATIO_QUARTERLY exists...
# Attempting to drop table META_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table META_RATIO_QUARTERLY
# Creating table META_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: META_RATIO_QUARTERLY
# Inserting into META_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: META_RATIO_QUARTERLY
# Checking if table SHEL_INCOME_QUARTERLY exists...
# Attempting to drop table SHEL_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SHEL_INCOME_QUARTERLY
# Creating table SHEL_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SHEL_INCOME_QUARTERLY
# Inserting into SHEL_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SHEL_INCOME_QUARTERLY
# Checking if table SHEL_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table SHEL_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SHEL_BALANCE_SHEET_QUARTERLY
# Creating table SHEL_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SHEL_BALANCE_SHEET_QUARTERLY
# Inserting into SHEL_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SHEL_BALANCE_SHEET_QUARTERLY
# Checking if table SHEL_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table SHEL_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SHEL_CASH_FLOW_QUARTERLY
# Creating table SHEL_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SHEL_CASH_FLOW_QUARTERLY
# Inserting into SHEL_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SHEL_CASH_FLOW_QUARTERLY
# Checking if table SHEL_RATIO_QUARTERLY exists...
# Attempting to drop table SHEL_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SHEL_RATIO_QUARTERLY
# Creating table SHEL_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SHEL_RATIO_QUARTERLY
# Inserting into SHEL_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SHEL_RATIO_QUARTERLY
# Checking if table MCD_INCOME_QUARTERLY exists...
# Attempting to drop table MCD_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MCD_INCOME_QUARTERLY
# Creating table MCD_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MCD_INCOME_QUARTERLY
# Inserting into MCD_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MCD_INCOME_QUARTERLY
# Checking if table MCD_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table MCD_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MCD_BALANCE_SHEET_QUARTERLY
# Creating table MCD_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MCD_BALANCE_SHEET_QUARTERLY
# Inserting into MCD_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MCD_BALANCE_SHEET_QUARTERLY
# Checking if table MCD_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table MCD_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MCD_CASH_FLOW_QUARTERLY
# Creating table MCD_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MCD_CASH_FLOW_QUARTERLY
# Inserting into MCD_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MCD_CASH_FLOW_QUARTERLY
# Checking if table MCD_RATIO_QUARTERLY exists...
# Attempting to drop table MCD_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MCD_RATIO_QUARTERLY
# Creating table MCD_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MCD_RATIO_QUARTERLY
# Inserting into MCD_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MCD_RATIO_QUARTERLY
# Checking if table KO_INCOME_QUARTERLY exists...
# Attempting to drop table KO_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table KO_INCOME_QUARTERLY
# Creating table KO_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: KO_INCOME_QUARTERLY
# Inserting into KO_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: KO_INCOME_QUARTERLY
# Checking if table KO_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table KO_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table KO_BALANCE_SHEET_QUARTERLY
# Creating table KO_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: KO_BALANCE_SHEET_QUARTERLY
# Inserting into KO_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: KO_BALANCE_SHEET_QUARTERLY
# Checking if table KO_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table KO_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table KO_CASH_FLOW_QUARTERLY
# Creating table KO_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: KO_CASH_FLOW_QUARTERLY
# Inserting into KO_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: KO_CASH_FLOW_QUARTERLY
# Checking if table KO_RATIO_QUARTERLY exists...
# Attempting to drop table KO_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table KO_RATIO_QUARTERLY
# Creating table KO_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: KO_RATIO_QUARTERLY
# Inserting into KO_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: KO_RATIO_QUARTERLY
# Checking if table GOOG_INCOME_QUARTERLY exists...
# Attempting to drop table GOOG_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table GOOG_INCOME_QUARTERLY
# Creating table GOOG_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: GOOG_INCOME_QUARTERLY
# Inserting into GOOG_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: GOOG_INCOME_QUARTERLY
# Checking if table GOOG_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table GOOG_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table GOOG_BALANCE_SHEET_QUARTERLY
# Creating table GOOG_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: GOOG_BALANCE_SHEET_QUARTERLY
# Inserting into GOOG_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: GOOG_BALANCE_SHEET_QUARTERLY
# Checking if table GOOG_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table GOOG_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table GOOG_CASH_FLOW_QUARTERLY
# Creating table GOOG_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: GOOG_CASH_FLOW_QUARTERLY
# Inserting into GOOG_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: GOOG_CASH_FLOW_QUARTERLY
# Checking if table GOOG_RATIO_QUARTERLY exists...
# Attempting to drop table GOOG_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table GOOG_RATIO_QUARTERLY
# Creating table GOOG_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: GOOG_RATIO_QUARTERLY
# Inserting into GOOG_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: GOOG_RATIO_QUARTERLY
# Checking if table VZ_INCOME_QUARTERLY exists...
# Attempting to drop table VZ_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table VZ_INCOME_QUARTERLY
# Creating table VZ_INCOME_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: VZ_INCOME_QUARTERLY
# Inserting into VZ_INCOME_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: VZ_INCOME_QUARTERLY
# Checking if table VZ_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table VZ_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table VZ_BALANCE_SHEET_QUARTERLY
# Creating table VZ_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: VZ_BALANCE_SHEET_QUARTERLY
# Inserting into VZ_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: VZ_BALANCE_SHEET_QUARTERLY
# Checking if table VZ_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table VZ_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table VZ_CASH_FLOW_QUARTERLY
# Creating table VZ_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: VZ_CASH_FLOW_QUARTERLY
# Inserting into VZ_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: VZ_CASH_FLOW_QUARTERLY
# Checking if table VZ_RATIO_QUARTERLY exists...
# Attempting to drop table VZ_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table VZ_RATIO_QUARTERLY
# Creating table VZ_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024',
#        'q4_2023', 'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: VZ_RATIO_QUARTERLY
# Inserting into VZ_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: VZ_RATIO_QUARTERLY
# Checking if table JPM_INCOME_QUARTERLY exists...
# Attempting to drop table JPM_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table JPM_INCOME_QUARTERLY
# Creating table JPM_INCOME_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: JPM_INCOME_QUARTERLY
# Inserting into JPM_INCOME_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: JPM_INCOME_QUARTERLY
# Checking if table JPM_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table JPM_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table JPM_BALANCE_SHEET_QUARTERLY
# Creating table JPM_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: JPM_BALANCE_SHEET_QUARTERLY
# Inserting into JPM_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: JPM_BALANCE_SHEET_QUARTERLY
# Checking if table JPM_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table JPM_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table JPM_CASH_FLOW_QUARTERLY
# Creating table JPM_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: JPM_CASH_FLOW_QUARTERLY
# Inserting into JPM_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: JPM_CASH_FLOW_QUARTERLY
# Checking if table JPM_RATIO_QUARTERLY exists...
# Attempting to drop table JPM_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table JPM_RATIO_QUARTERLY
# Creating table JPM_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024',
#        'q4_2023', 'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: JPM_RATIO_QUARTERLY
# Inserting into JPM_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: JPM_RATIO_QUARTERLY
# Checking if table AMZN_INCOME_QUARTERLY exists...
# Attempting to drop table AMZN_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMZN_INCOME_QUARTERLY
# Creating table AMZN_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMZN_INCOME_QUARTERLY
# Inserting into AMZN_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMZN_INCOME_QUARTERLY
# Checking if table AMZN_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table AMZN_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMZN_BALANCE_SHEET_QUARTERLY
# Creating table AMZN_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMZN_BALANCE_SHEET_QUARTERLY
# Inserting into AMZN_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMZN_BALANCE_SHEET_QUARTERLY
# Checking if table AMZN_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table AMZN_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMZN_CASH_FLOW_QUARTERLY
# Creating table AMZN_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMZN_CASH_FLOW_QUARTERLY
# Inserting into AMZN_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMZN_CASH_FLOW_QUARTERLY
# Checking if table AMZN_RATIO_QUARTERLY exists...
# Attempting to drop table AMZN_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMZN_RATIO_QUARTERLY
# Creating table AMZN_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMZN_RATIO_QUARTERLY
# Inserting into AMZN_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMZN_RATIO_QUARTERLY
# Checking if table TSLA_INCOME_QUARTERLY exists...
# Attempting to drop table TSLA_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table TSLA_INCOME_QUARTERLY
# Creating table TSLA_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: TSLA_INCOME_QUARTERLY
# Inserting into TSLA_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: TSLA_INCOME_QUARTERLY
# Checking if table TSLA_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table TSLA_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table TSLA_BALANCE_SHEET_QUARTERLY
# Creating table TSLA_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: TSLA_BALANCE_SHEET_QUARTERLY
# Inserting into TSLA_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: TSLA_BALANCE_SHEET_QUARTERLY
# Checking if table TSLA_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table TSLA_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table TSLA_CASH_FLOW_QUARTERLY
# Creating table TSLA_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: TSLA_CASH_FLOW_QUARTERLY
# Inserting into TSLA_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: TSLA_CASH_FLOW_QUARTERLY
# Checking if table TSLA_RATIO_QUARTERLY exists...
# Attempting to drop table TSLA_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table TSLA_RATIO_QUARTERLY
# Creating table TSLA_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: TSLA_RATIO_QUARTERLY
# Inserting into TSLA_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: TSLA_RATIO_QUARTERLY
# Checking if table NFLX_INCOME_QUARTERLY exists...
# Attempting to drop table NFLX_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table NFLX_INCOME_QUARTERLY
# Creating table NFLX_INCOME_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: NFLX_INCOME_QUARTERLY
# Inserting into NFLX_INCOME_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: NFLX_INCOME_QUARTERLY
# Checking if table NFLX_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table NFLX_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table NFLX_BALANCE_SHEET_QUARTERLY
# Creating table NFLX_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: NFLX_BALANCE_SHEET_QUARTERLY
# Inserting into NFLX_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: NFLX_BALANCE_SHEET_QUARTERLY
# Checking if table NFLX_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table NFLX_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table NFLX_CASH_FLOW_QUARTERLY
# Creating table NFLX_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: NFLX_CASH_FLOW_QUARTERLY
# Inserting into NFLX_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: NFLX_CASH_FLOW_QUARTERLY
# Checking if table NFLX_RATIO_QUARTERLY exists...
# Attempting to drop table NFLX_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table NFLX_RATIO_QUARTERLY
# Creating table NFLX_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q4_2024', 'q3_2024', 'q2_2024', 'q1_2024',
#        'q4_2023', 'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022'],
#       dtype='object')
# Created table: NFLX_RATIO_QUARTERLY
# Inserting into NFLX_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q4_2024', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022']
# ✅ Inserted data into: NFLX_RATIO_QUARTERLY
# Checking if table SPGI_INCOME_QUARTERLY exists...
# Attempting to drop table SPGI_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SPGI_INCOME_QUARTERLY
# Creating table SPGI_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SPGI_INCOME_QUARTERLY
# Inserting into SPGI_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SPGI_INCOME_QUARTERLY
# Checking if table SPGI_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table SPGI_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SPGI_BALANCE_SHEET_QUARTERLY
# Creating table SPGI_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SPGI_BALANCE_SHEET_QUARTERLY
# Inserting into SPGI_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SPGI_BALANCE_SHEET_QUARTERLY
# Checking if table SPGI_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table SPGI_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SPGI_CASH_FLOW_QUARTERLY
# Creating table SPGI_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SPGI_CASH_FLOW_QUARTERLY
# Inserting into SPGI_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SPGI_CASH_FLOW_QUARTERLY
# Checking if table SPGI_RATIO_QUARTERLY exists...
# Attempting to drop table SPGI_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table SPGI_RATIO_QUARTERLY
# Creating table SPGI_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: SPGI_RATIO_QUARTERLY
# Inserting into SPGI_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: SPGI_RATIO_QUARTERLY
# Checking if table HSBC_INCOME_QUARTERLY exists...
# Attempting to drop table HSBC_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table HSBC_INCOME_QUARTERLY
# Creating table HSBC_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: HSBC_INCOME_QUARTERLY
# Inserting into HSBC_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: HSBC_INCOME_QUARTERLY
# Checking if table HSBC_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table HSBC_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table HSBC_BALANCE_SHEET_QUARTERLY
# Creating table HSBC_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: HSBC_BALANCE_SHEET_QUARTERLY
# Inserting into HSBC_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: HSBC_BALANCE_SHEET_QUARTERLY
# Checking if table HSBC_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table HSBC_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table HSBC_CASH_FLOW_QUARTERLY
# Creating table HSBC_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: HSBC_CASH_FLOW_QUARTERLY
# Inserting into HSBC_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: HSBC_CASH_FLOW_QUARTERLY
# Checking if table HSBC_RATIO_QUARTERLY exists...
# Attempting to drop table HSBC_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table HSBC_RATIO_QUARTERLY
# Creating table HSBC_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: HSBC_RATIO_QUARTERLY
# Inserting into HSBC_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: HSBC_RATIO_QUARTERLY
# Checking if table MA_INCOME_QUARTERLY exists...
# Attempting to drop table MA_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MA_INCOME_QUARTERLY
# Creating table MA_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MA_INCOME_QUARTERLY
# Inserting into MA_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MA_INCOME_QUARTERLY
# Checking if table MA_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table MA_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MA_BALANCE_SHEET_QUARTERLY
# Creating table MA_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MA_BALANCE_SHEET_QUARTERLY
# Inserting into MA_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MA_BALANCE_SHEET_QUARTERLY
# Checking if table MA_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table MA_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MA_CASH_FLOW_QUARTERLY
# Creating table MA_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MA_CASH_FLOW_QUARTERLY
# Inserting into MA_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MA_CASH_FLOW_QUARTERLY
# Checking if table MA_RATIO_QUARTERLY exists...
# Attempting to drop table MA_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table MA_RATIO_QUARTERLY
# Creating table MA_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: MA_RATIO_QUARTERLY
# Inserting into MA_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: MA_RATIO_QUARTERLY
# Checking if table AMD_INCOME_QUARTERLY exists...
# Attempting to drop table AMD_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMD_INCOME_QUARTERLY
# Creating table AMD_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMD_INCOME_QUARTERLY
# Inserting into AMD_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMD_INCOME_QUARTERLY
# Checking if table AMD_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table AMD_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMD_BALANCE_SHEET_QUARTERLY
# Creating table AMD_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMD_BALANCE_SHEET_QUARTERLY
# Inserting into AMD_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMD_BALANCE_SHEET_QUARTERLY
# Checking if table AMD_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table AMD_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMD_CASH_FLOW_QUARTERLY
# Creating table AMD_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMD_CASH_FLOW_QUARTERLY
# Inserting into AMD_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMD_CASH_FLOW_QUARTERLY
# Checking if table AMD_RATIO_QUARTERLY exists...
# Attempting to drop table AMD_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table AMD_RATIO_QUARTERLY
# Creating table AMD_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: AMD_RATIO_QUARTERLY
# Inserting into AMD_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: AMD_RATIO_QUARTERLY
# Checking if table PEP_INCOME_QUARTERLY exists...
# Attempting to drop table PEP_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table PEP_INCOME_QUARTERLY
# Creating table PEP_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: PEP_INCOME_QUARTERLY
# Inserting into PEP_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: PEP_INCOME_QUARTERLY
# Checking if table PEP_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table PEP_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table PEP_BALANCE_SHEET_QUARTERLY
# Creating table PEP_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: PEP_BALANCE_SHEET_QUARTERLY
# Inserting into PEP_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: PEP_BALANCE_SHEET_QUARTERLY
# Checking if table PEP_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table PEP_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table PEP_CASH_FLOW_QUARTERLY
# Creating table PEP_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: PEP_CASH_FLOW_QUARTERLY
# Inserting into PEP_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: PEP_CASH_FLOW_QUARTERLY
# Checking if table PEP_RATIO_QUARTERLY exists...
# Attempting to drop table PEP_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table PEP_RATIO_QUARTERLY
# Creating table PEP_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: PEP_RATIO_QUARTERLY
# Inserting into PEP_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: PEP_RATIO_QUARTERLY
# Checking if table T_INCOME_QUARTERLY exists...
# Attempting to drop table T_INCOME_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table T_INCOME_QUARTERLY
# Creating table T_INCOME_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: T_INCOME_QUARTERLY
# Inserting into T_INCOME_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: T_INCOME_QUARTERLY
# Checking if table T_BALANCE_SHEET_QUARTERLY exists...
# Attempting to drop table T_BALANCE_SHEET_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table T_BALANCE_SHEET_QUARTERLY
# Creating table T_BALANCE_SHEET_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: T_BALANCE_SHEET_QUARTERLY
# Inserting into T_BALANCE_SHEET_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: T_BALANCE_SHEET_QUARTERLY
# Checking if table T_CASH_FLOW_QUARTERLY exists...
# Attempting to drop table T_CASH_FLOW_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table T_CASH_FLOW_QUARTERLY
# Creating table T_CASH_FLOW_QUARTERLY with columns: Index(['metrics', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023', 'q3_2023',
#        'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: T_CASH_FLOW_QUARTERLY
# Inserting into T_CASH_FLOW_QUARTERLY with columns: ['METRICS', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: T_CASH_FLOW_QUARTERLY
# Checking if table T_RATIO_QUARTERLY exists...
# Attempting to drop table T_RATIO_QUARTERLY (Attempt 1/5)
# ✅ Successfully dropped table T_RATIO_QUARTERLY
# Creating table T_RATIO_QUARTERLY with columns: Index(['metrics', 'current_2025', 'q3_2024', 'q2_2024', 'q1_2024', 'q4_2023',
#        'q3_2023', 'q2_2023', 'q1_2023', 'q4_2022', 'q3_2022'],
#       dtype='object')
# Created table: T_RATIO_QUARTERLY
# Inserting into T_RATIO_QUARTERLY with columns: ['METRICS', 'CURRENT_2025', 'Q3_2024', 'Q2_2024', 'Q1_2024', 'Q4_2023', 'Q3_2023', 'Q2_2023', 'Q1_2023', 'Q4_2022', 'Q3_2022']
# ✅ Inserted data into: T_RATIO_QUARTERLY
# All files and sheets uploaded successfully.

# %%
import os
import oracledb

# Oracle DB connection details
user = "ADMIN"
password = "Passwordtestdb@1"
dsn = "testdb_medium"
wallet_location = r"/Users/vexy/Documents/Wallet_testdb/"

# Connect to Oracle DB
conn = oracledb.connect(
    user=user,
    password=password,
    dsn=dsn,
    
    config_dir=wallet_location,
    wallet_location=wallet_location,
    wallet_password=password
)
cursor = conn.cursor()

# Output directory for DDL files
output_dir = "/Users/vexy/Documents/Oracle_DDLs"
os.makedirs(output_dir, exist_ok=True)

# Extract all table DDLs
cursor.execute("SELECT TABLE_NAME, DBMS_METADATA.GET_DDL('TABLE', TABLE_NAME) FROM USER_TABLES")
ddl_data = cursor.fetchall()

# Dictionary to store DDLs by company
company_ddls = {}

# Save all DDLs in a single file
all_ddl_file = os.path.join(output_dir, "all_tables.sql")
with open(all_ddl_file, "w", encoding="utf-8") as all_file:
    for table_name, ddl in ddl_data:
        ddl_text = ddl.read()  # Convert CLOB to string
        company_name = table_name.split("_")[0]  # Extract first word

        # Save DDL into the dictionary for respective company
        if company_name not in company_ddls:

            company_ddls[company_name] = []
        company_ddls[company_name].append(ddl_text)

        # Write to the all_tables.sql file
        all_file.write(f"-- DDL for {table_name}\n")
        all_file.write(ddl_text + "\n\n")

print(f"Saved all table DDLs to: {all_ddl_file}")

# Create individual .sql files for each company
for company, ddls in company_ddls.items():
    company_file = os.path.join(output_dir, f"{company}_ddl.sql")
    with open(company_file, "w", encoding="utf-8") as company_sql:
        for ddl in ddls:
            company_sql.write(ddl + "\n\n")
    print(f"Saved {company} DDLs to: {company_file}")

# Close the connection
cursor.close()
conn.close()
print("DDL extraction and file generation complete.")
# Out:
# Saved all table DDLs to: /Users/vexy/Documents/Oracle_DDLs/all_tables.sql
# Saved META DDLs to: /Users/vexy/Documents/Oracle_DDLs/META_ddl.sql
# Saved SHEL DDLs to: /Users/vexy/Documents/Oracle_DDLs/SHEL_ddl.sql
# Saved MCD DDLs to: /Users/vexy/Documents/Oracle_DDLs/MCD_ddl.sql
# Saved KO DDLs to: /Users/vexy/Documents/Oracle_DDLs/KO_ddl.sql
# Saved GOOG DDLs to: /Users/vexy/Documents/Oracle_DDLs/GOOG_ddl.sql
# Saved VZ DDLs to: /Users/vexy/Documents/Oracle_DDLs/VZ_ddl.sql
# Saved JPM DDLs to: /Users/vexy/Documents/Oracle_DDLs/JPM_ddl.sql
# Saved AMZN DDLs to: /Users/vexy/Documents/Oracle_DDLs/AMZN_ddl.sql
# Saved TSLA DDLs to: /Users/vexy/Documents/Oracle_DDLs/TSLA_ddl.sql
# Saved NFLX DDLs to: /Users/vexy/Documents/Oracle_DDLs/NFLX_ddl.sql
# Saved SPGI DDLs to: /Users/vexy/Documents/Oracle_DDLs/SPGI_ddl.sql
# Saved HSBC DDLs to: /Users/vexy/Documents/Oracle_DDLs/HSBC_ddl.sql
# Saved MA DDLs to: /Users/vexy/Documents/Oracle_DDLs/MA_ddl.sql
# Saved AMD DDLs to: /Users/vexy/Documents/Oracle_DDLs/AMD_ddl.sql
# Saved PEP DDLs to: /Users/vexy/Documents/Oracle_DDLs/PEP_ddl.sql
# Saved T DDLs to: /Users/vexy/Documents/Oracle_DDLs/T_ddl.sql
# DDL extraction and file generation complete.

# %%
import os
import oracledb

# Oracle DB connection details
user = "ADMIN"
password = "Passwordtestdb@1"
dsn = "testdb_medium"
wallet_location = r"/Users/vexy/Documents/Wallet_testdb/"

# Paths for output
ddl_directory = "/Users/vexy/Documents/Oracle_DDLs"
metrics_output_file = os.path.join(ddl_directory, "metrics_values.txt")
error_log_file = os.path.join(ddl_directory, "error_log.txt")

# Connect to Oracle DB
conn = oracledb.connect(
    user=user,
    password=password,
    dsn=dsn,
    config_dir=wallet_location,
    wallet_location=wallet_location,
    wallet_password=password
)
cursor = conn.cursor()

# Step 1: Extract "Metrics" column values for each table
cursor.execute("SELECT TABLE_NAME FROM USER_TABLES")
table_names = [row[0] for row in cursor.fetchall()]

# Open files for writing results and errors
with open(metrics_output_file, "w", encoding="utf-8") as f, open(error_log_file, "w", encoding="utf-8") as error_log:
    for table in table_names:
        try:
            # Check if "Metrics" column exists (case-insensitive)
            cursor.execute(f"SELECT COLUMN_NAME FROM USER_TAB_COLUMNS WHERE TABLE_NAME = '{table}'")
            columns = {row[0].upper(): row[0] for row in cursor.fetchall()}  # Preserve case

            if "METRICS" not in columns:
                msg = f"⚠️ Skipping {table}: 'Metrics' column not found.\n"
                print(msg.strip())
                error_log.write(msg)
                continue  # Skip tables without "Metrics" column

            metrics_column = columns["METRICS"]  # Correct case for querying
            cursor.execute(f'SELECT "{metrics_column}" FROM "{table}"')
            metrics = [row[0] for row in cursor.fetchall()]

            if metrics:
                f.write(f"-- Metrics for {table}\n")
                for metric in metrics:
                    f.write(f"{metric}\n")
                f.write("\n")

                print(f"✅ Extracted metrics for: {table}")

        except oracledb.DatabaseError as e:
            msg = f"⚠️ Error in {table}: {e}\n"
            print(msg.strip())
            error_log.write(msg)

print(f"📂 All metrics extracted and saved to: {metrics_output_file}")
print(f"📝 Error log saved to: {error_log_file}")

# Close connection
cursor.close()
conn.close()
# Out:
# ✅ Extracted metrics for: META_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: META_INCOME_QUARTERLY
# ✅ Extracted metrics for: META_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: META_RATIO_QUARTERLY
# ✅ Extracted metrics for: SHEL_INCOME_QUARTERLY
# ✅ Extracted metrics for: SHEL_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: SHEL_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: SHEL_RATIO_QUARTERLY
# ✅ Extracted metrics for: MCD_INCOME_QUARTERLY
# ✅ Extracted metrics for: MCD_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: MCD_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: MCD_RATIO_QUARTERLY
# ✅ Extracted metrics for: KO_INCOME_QUARTERLY
# ✅ Extracted metrics for: KO_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: KO_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: KO_RATIO_QUARTERLY
# ✅ Extracted metrics for: GOOG_INCOME_QUARTERLY
# ✅ Extracted metrics for: GOOG_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: GOOG_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: GOOG_RATIO_QUARTERLY
# ✅ Extracted metrics for: VZ_INCOME_QUARTERLY
# ✅ Extracted metrics for: VZ_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: VZ_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: VZ_RATIO_QUARTERLY
# ✅ Extracted metrics for: JPM_INCOME_QUARTERLY
# ✅ Extracted metrics for: JPM_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: JPM_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: JPM_RATIO_QUARTERLY
# ✅ Extracted metrics for: AMZN_INCOME_QUARTERLY
# ✅ Extracted metrics for: AMZN_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: AMZN_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: AMZN_RATIO_QUARTERLY
# ✅ Extracted metrics for: TSLA_INCOME_QUARTERLY
# ✅ Extracted metrics for: TSLA_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: TSLA_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: TSLA_RATIO_QUARTERLY
# ✅ Extracted metrics for: NFLX_INCOME_QUARTERLY
# ✅ Extracted metrics for: NFLX_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: NFLX_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: NFLX_RATIO_QUARTERLY
# ✅ Extracted metrics for: SPGI_INCOME_QUARTERLY
# ✅ Extracted metrics for: SPGI_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: SPGI_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: SPGI_RATIO_QUARTERLY
# ✅ Extracted metrics for: HSBC_INCOME_QUARTERLY
# ✅ Extracted metrics for: HSBC_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: HSBC_RATIO_QUARTERLY
# ✅ Extracted metrics for: MA_INCOME_QUARTERLY
# ✅ Extracted metrics for: MA_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: MA_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: MA_RATIO_QUARTERLY
# ✅ Extracted metrics for: AMD_INCOME_QUARTERLY
# ✅ Extracted metrics for: AMD_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: AMD_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: AMD_RATIO_QUARTERLY
# ✅ Extracted metrics for: PEP_INCOME_QUARTERLY
# ✅ Extracted metrics for: PEP_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: PEP_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: PEP_RATIO_QUARTERLY
# ✅ Extracted metrics for: T_INCOME_QUARTERLY
# ✅ Extracted metrics for: T_BALANCE_SHEET_QUARTERLY
# ✅ Extracted metrics for: T_CASH_FLOW_QUARTERLY
# ✅ Extracted metrics for: T_RATIO_QUARTERLY
# 📂 All metrics extracted and saved to: /Users/vexy/Documents/Oracle_DDLs/metrics_values.txt
# 📝 Error log saved to: /Users/vexy/Documents/Oracle_DDLs/error_log.txt

# %%
import os
import re

# Define file paths
ddl_folder = r"/Users/vexy/Documents/Oracle_DDLs"  # Path to DDL files
metrics_file_path = r"/Users/vexy/Documents/Oracle_DDLs/metrics_values.txt"  # Path to metrics_values.txt

# Read the metrics file
with open(metrics_file_path, "r", encoding="utf-8") as f:
    metrics_content = f.read()

# Extract metric values grouped by table names
metrics_data = {}
matches = re.findall(r"-- Metrics for (\S+)\n([\s\S]+?)(?=\n-- Metrics for |\Z)", metrics_content)

for table_name, values in matches:
    table_name = table_name.strip().upper()  # Convert to uppercase for matching
    metrics_data[table_name] = [line.strip() for line in values.split("\n") if line.strip()]

# Process each DDL file
for ddl_file in os.listdir(ddl_folder):
    if ddl_file.endswith(".sql"):
        file_path = os.path.join(ddl_folder, ddl_file)

        # Read DDL content
        with open(file_path, "r", encoding="utf-8") as f:
            ddl_lines = f.readlines()

        cleaned_ddl = []
        in_insert_block = False

        for line in ddl_lines:
            # Remove old INSERT INTO statements
            if re.search(r'INSERT INTO "ADMIN"\."(\S+)"', line, re.IGNORECASE):
                in_insert_block = True
                continue  # Skip old insert statements
            if in_insert_block and line.strip() == "":  # End of insert block
                in_insert_block = False
                continue
            if not in_insert_block:
                cleaned_ddl.append(line)  # Keep everything else

        updated_ddl = []
        current_table = None
        column_name_map = {}  # Store exact column names for each table

        # First pass: Extract correct column names from CREATE TABLE
        for line in cleaned_ddl:
            updated_ddl.append(line)

            table_match = re.search(r'CREATE TABLE "ADMIN"\."(\S+)"', line, re.IGNORECASE)
            column_match = re.search(r'"(\S+)"\s+VARCHAR2', line, re.IGNORECASE)

            if table_match:
                current_table = table_match.group(1).upper()  # Convert table name to uppercase for matching
                column_name_map[current_table] = None  # Initialize column mapping

            if column_match and current_table:
                column_name_map[current_table] = column_match.group(1)  # Store the exact column name

        # Second pass: Add INSERT statements immediately after CREATE TABLE
        final_ddl = []
        for line in updated_ddl:
            final_ddl.append(line)

            table_match = re.search(r'CREATE TABLE "ADMIN"\."(\S+)"', line, re.IGNORECASE)
            if table_match:
                current_table = table_match.group(1).upper()  # Convert table name to uppercase for matching

                if current_table in metrics_data and current_table in column_name_map:
                    column_name = column_name_map[current_table]  # Get exact column name

                    # Construct a single INSERT statement with all values inside single quotes ''
                    values_str = ",\n".join([f"""("{value}")""" for value in metrics_data[current_table]])

                    insert_stmt = f'\n-- Insert values into the {column_name} column for {current_table}\n'
                    insert_stmt += f'INSERT INTO "ADMIN"."{current_table}" ("{column_name}") VALUES\n{values_str};\n'

                    final_ddl.append(insert_stmt)  # Insert statement directly after CREATE TABLE

        # Save the cleaned and updated DDL file
        with open(file_path, "w", encoding="utf-8") as f:
            f.writelines(final_ddl)

        print(f"✅ Successfully updated {ddl_file} with corrected INSERT statements.")

print("🎯 All DDLs processed successfully.")
# Out:
# ✅ Successfully updated META_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated HSBC_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated T_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated KO_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated AMZN_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated SHEL_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated MCD_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated GOOG_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated SPGI_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated JPM_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated all_tables.sql with corrected INSERT statements.
# ✅ Successfully updated NFLX_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated VZ_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated MA_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated AMD_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated PEP_ddl.sql with corrected INSERT statements.
# ✅ Successfully updated TSLA_ddl.sql with corrected INSERT statements.
# 🎯 All DDLs processed successfully.
